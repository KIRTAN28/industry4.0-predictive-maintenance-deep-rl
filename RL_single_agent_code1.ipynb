# %% [markdown]
# <a href="https://colab.research.google.com/github/KIRTAN28/industry4.0-predictive-maintenance-deep-rl/blob/main/RL_single_agent_code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
from typing import Optional, Union, Tuple, Dict
from collections import deque
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError

# --- ENVIRONMENT: PredictiveMaintenanceEnv ---

class PredictiveMaintenanceEnv(gym.Env):
    """
    Observation space (10 features per component):
    [tᵢ, Δt_last, λᵢ, Rᵢ, RULᵢ, MTTFᵢ, Lᵢ, MTTRᵢ, a_prev, Cᵢ]

    Action space (MultiDiscrete[3] * N): 0=NOOP, 1=PM, 2=CM
    """
    metadata = {"render_modes": ["human"], "render_fps": 1}

    def __init__(self, time_step: float = 1.0, render_mode: Optional[str] = None):
        super(PredictiveMaintenanceEnv, self).__init__()

        # Environment Configuration
        self.TIME_STEP = time_step
        self.render_mode = render_mode

        # Termination parameters
        self.MAX_AGE_TERMINATION = 10000.0
        self.RELIABILITY_THRESHOLD = 0.15 # Episode terminates if R < 15%

        # Weibull parameters for components (β = shape, η = scale)
        self.components = {
            #"Acc Piston": {"beta": 2.69, "eta": 3744},
            "Electrodes" : {"beta" : 1.61,"eta" : 2388}
        }

        self.num_components = len(self.components)
        self.component_names = list(self.components.keys())

        # Cost Parameters (ADJUSTED TO USER REQUIREMENTS)
        self.COST_OP_HOUR_BASE = 10.0
        # Increased significantly to incentivize early PM (Requirement 2)
        self.OP_HAZARD_SCALE = 40000.0          # Factor to make operating cost increase aggressively with low hazard rate

        self.COST_PM_FIXED_BASE = 3000.0        # FIXED PM cost
        self.COST_CM_FIXED_BASE = 15000.0       # CM cost remains 15000 Rs

        self.COST_DOWN_HOUR = 500.0
        self.PENALTY_UNPLANNED_FAIL = 100000.0
        self.DOWNTIME_PM_HRS = 8.0
        self.MTTR_R_PENALTY = 5.0               # Factor to make MTTR increase aggressively with low reliability

        # Imperfect Maintenance Parameter (NEW Requirement)
        self.PM_RESTORATION_FACTOR = 0.85 # Max R after PM is 85% of R at time of PM

        # State Initialization
        self.ages = np.zeros(self.num_components)        # Weibull Age (resets/reduces on PM/CM)
        self.time_since_maintenance = np.zeros(self.num_components)
        self.last_action = np.zeros(self.num_components)
        self.load_fraction = np.ones(self.num_components) * 0.8

        # Spaces
        self.action_space = spaces.MultiDiscrete([3] * self.num_components)
        self.observation_space = spaces.Box(
            low=0.0, high=np.inf, shape=(self.num_components, 10), dtype=np.float32,
        )

    # --- Weibull helper functions ---

    def _calculate_age_for_reliability(self, target_R: float, component_index: int) -> float:
        """
        Calculates the age (t) at which reliability R(t) equals target_R
        for a specific component's Weibull parameters.
        """
        params = self.components[self.component_names[component_index]]
        beta, eta = params["beta"], params["eta"]

        # R(t) = exp(-(t/eta)^beta) = target_R
        # (t/eta)^beta = -ln(target_R)
        # t = eta * (-ln(target_R))^(1/beta)
        try:
            # Added small epsilon check: if target_R is 1.0 (or very close), age must be 0.0
            if target_R >= 1.0 - 1e-9 or target_R <= 0.0: return 0.0

            # Ensure target_R is slightly below 1.0 for the logarithm
            target_R = max(1e-9, min(target_R, 1.0 - 1e-9))

            t_prime = eta * ((-math.log(target_R)) ** (1 / beta))
            return t_prime
        except ValueError:
            return 0.0

    def hazard_rate(self, t: float, beta: float, eta: float) -> float:
        """Instantaneous failure rate (Weibull hazard function)."""
        if t <= 0.0: return 0.0
        return (beta / eta) * ((t / eta) ** (beta - 1))

    def reliability(self, t: float, beta: float, eta: float) -> float:
        """Probability of survival until time t."""
        return np.exp(-((t / eta) ** beta))

    def mean_time_to_failure(self, beta: float, eta: float) -> float:
        """Expected lifespan of the component."""
        return eta * math.gamma(1 + 1 / beta)

    def remaining_useful_life(self, t: float, beta: float, eta: float, threshold: float = 0.1) -> float:
        """Time remaining until reliability drops below the threshold."""
        try:
            R_current = self.reliability(t, beta, eta)
            if R_current <= threshold: return 0.0
            t_threshold = eta * ((-math.log(threshold)) ** (1 / beta))
            RUL = t_threshold - t
            return max(0.0, RUL)
        except ValueError:
            return 0.0

    def mean_time_to_repair(self, reliability: float) -> float:
        """
        Calculates MTTR, where repair time increases significantly as reliability drops.
        (Requirement 3: Downtime cost increases with low R)
        """
        # Dynamic Scaling: Factor increases as (1 - R) increases.
        scaling_factor = 1.0 + (self.MTTR_R_PENALTY * (1.0 - reliability))

        # Base mean rates (1/hours)
        CMT_rate = 0.05
        TTAS_rate = 0.1
        TTAP_rate = 0.1

        # Mean times increase with scaling_factor
        CMT = (1 / CMT_rate) * scaling_factor
        TTAS = (1 / TTAS_rate) * scaling_factor
        TTAP = (1 / TTAP_rate) * scaling_factor

        MDT = max(TTAS, TTAP)
        MTTR = CMT + MDT
        return MTTR

    # --- Environment core methods ---
    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None) -> Tuple[np.ndarray, Dict]:
        super().reset(seed=seed)
        self.ages.fill(0.0)
        self.time_since_maintenance.fill(0.0)
        self.last_action.fill(0.0)
        return self._get_state(), {}

    def step(self, actions: Union[np.ndarray, list]) -> Tuple[np.ndarray, float, bool, bool, Dict]:
        actions = np.array(actions)
        total_reward = 0.0
        info = {}

        terminate_max_age = False
        terminate_low_reliability = False
        running_cost_total = 0.0

        for i, (name, params) in enumerate(self.components.items()):
            beta, eta = params["beta"], params["eta"]

            # Calculate state BEFORE action to determine costs/reliability
            hazard = self.hazard_rate(self.ages[i], beta, eta)
            reliability = self.reliability(self.ages[i], beta, eta)

            # 1. DYNAMIC OPERATION COST
            cost_op = self.COST_OP_HOUR_BASE * (1.0 + self.OP_HAZARD_SCALE * hazard)
            running_cost_total += cost_op

            component_mttr = self.mean_time_to_repair(reliability)

            # Check for failure probability
            prob_failure = 1.0 - np.exp(-hazard * self.TIME_STEP)
            failed_spontaneously = np.random.rand() < prob_failure


            # --- Maintenance Handling ---
            maintenance_occurred = False

            if actions[i] == 1:  # Preventive Maintenance (PM)
                maintenance_occurred = True

                cost_pm_fixed = self.COST_PM_FIXED_BASE
                cost_downtime = self.COST_DOWN_HOUR
                total_reward -= (cost_pm_fixed + cost_downtime)

                # IMPERFECT RESTORATION FIX: R_target = R_current * Factor
                # We remove the max(R_current, ...) which prevented age from progressing when R was 1.0
                R_current = reliability
                R_target = R_current * self.PM_RESTORATION_FACTOR

                # If component is brand new (R=1.0) and PM is done, the best we can do is reset to 0.0.
                # However, R_target will be 0.85, giving a small effective age, which seems to be the intent
                # of "imperfect" maintenance.

                t_prime = self._calculate_age_for_reliability(R_target, i)

                self.ages[i] = t_prime
                self.time_since_maintenance[i] = 0.0

            elif actions[i] == 2:  # Corrective Maintenance (CM) (Replacement)
                maintenance_occurred = True

                dynamic_cm_fixed_cost = self.COST_CM_FIXED_BASE
                cost_downtime = self.COST_DOWN_HOUR * component_mttr
                cost_cm = dynamic_cm_fixed_cost

                total_reward -= (cost_cm + cost_downtime)
                self.ages[i] = 0.0 # Full replacement (as-good-as-new)
                self.time_since_maintenance[i] = 0.0

            elif actions[i] == 0: # Do Nothing (NOOP)
                 if failed_spontaneously:
                    maintenance_occurred = True

                    # Forced CM due to unplanned failure (most costly outcome)
                    dynamic_cm_fixed_cost = self.COST_CM_FIXED_BASE
                    cost_downtime = self.COST_DOWN_HOUR * component_mttr
                    cost_cm = dynamic_cm_fixed_cost + self.PENALTY_UNPLANNED_FAIL

                    total_reward -= (cost_cm + cost_downtime)
                    self.ages[i] = 0.0
                    self.time_since_maintenance[i] = 0.0

            # Age update
            # Age and TSM progress only if NOOP and no failure, OR if maintenance did not occur this step.
            if not maintenance_occurred:
                self.ages[i] += self.TIME_STEP
                self.time_since_maintenance[i] += self.TIME_STEP

            # Check for termination conditions
            if self.ages[i] >= self.MAX_AGE_TERMINATION:
                terminate_max_age = True

            # Re-calculate reliability with the (possibly) new age
            current_reliability = self.reliability(self.ages[i], beta, eta)
            if current_reliability <= self.RELIABILITY_THRESHOLD:
                terminate_low_reliability = True

            self.last_action[i] = actions[i]

        # --- System Running Cost ---
        total_reward -= running_cost_total * self.TIME_STEP

        # --- Termination Condition ---
        done = terminate_max_age or terminate_low_reliability

        next_state = self._get_state()

        return next_state, total_reward, done, False, info

    # Construct observation matrix
    def _get_state(self) -> np.ndarray:
        state = []
        for i, (name, params) in enumerate(self.components.items()):
            beta, eta = params["beta"], params["eta"]
            age = self.ages[i]

            hazard = self.hazard_rate(age, beta, eta)
            reliability = self.reliability(age, beta, eta)
            RUL = self.remaining_useful_life(age, beta, eta)
            MTTF = self.mean_time_to_failure(beta, eta)
            MTTR = self.mean_time_to_repair(reliability) # Calculate based on R
            load_fraction = self.load_fraction[i]
            confidence = reliability

            s_i = [
                age,                                   # 1. tᵢ (Weibull Age)
                self.time_since_maintenance[i],        # 2. Δt_last,i
                hazard,                                # 3. λᵢ
                reliability,                           # 4. Rᵢ
                RUL,                                   # 5. RULᵢ
                MTTF,                                  # 6. MTTFᵢ
                load_fraction,                         # 7. Lᵢ
                MTTR,                                  # 8. MTTRᵢ
                self.last_action[i],                   # 9. a_{prev},i
                confidence,                            # 10. Cᵢ
            ]
            state.append(s_i)
        return np.array(state, dtype=np.float32)

    def render(self):
        pass

    def close(self):
        pass

# --- DDQN AGENT IMPLEMENTATION (Standard) ---

class ReplayBuffer:
    """Stores experiences for DDQN training."""
    def __init__(self, capacity: int):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        if len(self.buffer) < batch_size: return []
        return random.sample(self.buffer, batch_size)

    def __len__(self):
        return len(self.buffer)

class DDQNAgent:
    """Double Deep Q-Network Agent."""
    def __init__(self, state_shape, action_dim, gamma=0.99, lr=0.001, epsilon=1.0, epsilon_min=0.01, epsilon_decay=0.9999, buffer_size=50000, batch_size=64, update_target_freq=100):

        self.state_shape = state_shape
        self.action_dim = action_dim
        self.num_components = state_shape[0]
        self.output_dim = self.action_dim ** self.num_components

        self.gamma = gamma
        self.lr = lr
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.batch_size = batch_size
        self.update_target_freq = update_target_freq
        self.memory = ReplayBuffer(buffer_size)
        self.train_step_count = 0

        self.q_local = self._build_model()
        self.q_target = self._build_model()
        self.q_target.set_weights(self.q_local.get_weights())

    def _build_model(self):
        """Creates a Neural Network for the Q-function."""
        model = Sequential()
        model.add(InputLayer(input_shape=self.state_shape))
        model.add(tf.keras.layers.Flatten())

        model.add(Dense(256, activation='relu'))
        model.add(Dense(128, activation='relu'))

        model.add(Dense(self.output_dim, activation='linear'))

        model.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=self.lr))
        return model

    def get_action(self, state: np.ndarray) -> np.ndarray:
        """Epsilon-greedy action selection."""
        if np.random.rand() <= self.epsilon:
            actions = np.random.randint(0, self.action_dim, size=self.num_components)
        else:
            state = np.expand_dims(state, axis=0)
            q_values = self.q_local.predict(state, verbose=0)[0]
            flat_action = np.argmax(q_values)
            actions = self._flat_to_multi_discrete(flat_action)

        return actions

    def _flat_to_multi_discrete(self, flat_action: int) -> np.ndarray:
        """Converts flat action index back to MultiDiscrete action array."""
        actions = []
        base = self.action_dim
        temp_action = flat_action
        for _ in range(self.num_components):
            action_i = temp_action % base
            actions.append(action_i)
            temp_action //= base
        return np.array(actions[::-1])

    def _multi_discrete_to_flat(self, actions: np.ndarray) -> int:
        """Converts MultiDiscrete action array to flat action index."""
        flat_action = 0
        base = self.action_dim
        for i, action_i in enumerate(reversed(actions)):
            flat_action += action_i * (base ** i)
        return flat_action

    def train(self):
        """Trains the Q-network using DDQN logic."""
        if len(self.memory) < self.batch_size:
            return

        batch = self.memory.sample(self.batch_size)

        states = np.array([exp[0] for exp in batch])
        actions_md = np.array([exp[1] for exp in batch])
        rewards = np.array([exp[2] for exp in batch])
        next_states = np.array([exp[3] for exp in batch])
        dones = np.array([exp[4] for exp in batch])

        q_values_local = self.q_local.predict(states, verbose=0)
        q_next_local = self.q_local.predict(next_states, verbose=0)
        max_action_indices_flat = np.argmax(q_next_local, axis=1)

        q_next_target = self.q_target.predict(next_states, verbose=0)
        q_target_evaluated = q_next_target[np.arange(self.batch_size), max_action_indices_flat]

        target_q_values = rewards + self.gamma * q_target_evaluated * (1 - dones)

        q_targets = q_values_local.copy()
        for i in range(self.batch_size):
            flat_action = self._multi_discrete_to_flat(actions_md[i])
            q_targets[i, flat_action] = target_q_values[i]

        self.q_local.fit(states, q_targets, epochs=1, verbose=0)

        self.train_step_count += 1
        if self.train_step_count % self.update_target_freq == 0:
            self.q_target.set_weights(self.q_local.get_weights())

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# --- TRAINING EXECUTION ---

REWARD_SCALE_FACTOR = 1000.0 # Divide all rewards/penalties by 1000

def train_ddqn():
    # Set seed for reproducibility
    tf.random.set_seed(42)
    np.random.seed(42)
    random.seed(42)

    # Environment Setup
    # Time step of 1.0 means each step is 1 hour
    env = PredictiveMaintenanceEnv(time_step=1.0)
    state_shape = env.observation_space.shape
    action_dim = env.action_space.nvec[0]
    num_components = env.num_components

    # Agent Setup
    agent = DDQNAgent(
        state_shape=state_shape,
        action_dim=action_dim,
        lr=0.0005,
        epsilon_decay=0.9995,
        buffer_size=50000,
        batch_size=32,
        update_target_freq=50
    )

    EPISODES = 100
    # Log at every step (1 step = 1 hour)
    LOG_STEP_INTERVAL = 1
    ACTION_MAP = {0: "NOOP", 1: "PM (Planned)", 2: "CM (Corrective)"}

    print("--- DDQN Training Start ---")
    print("Environment: {num_components} Component. Max Age: {env.MAX_AGE_TERMINATION} hrs. R_min: {env.RELIABILITY_THRESHOLD}")
    print("PM Fixed Cost: {env.COST_PM_FIXED_BASE:,.0f} Rs")
    print("PM Imperfect Restoration: {env.PM_RESTORATION_FACTOR * 100:.0f}% of R_prev")
    print("MTTR Reliability Penalty (x): {env.MTTR_R_PENALTY}")
    print("Operating Cost Hazard Scale (x): {env.OP_HAZARD_SCALE:,.0f} (Highly Aggressive)")
    print("Reward Scaling: 1 / {REWARD_SCALE_FACTOR:.0f}")

    for episode in range(1, EPISODES + 1):
        state, _ = env.reset()
        done = False
        episode_reward_raw = 0
        episode_reward_scaled = 0
        step_count = 0

        while not done:
            actions = agent.get_action(state)
            next_state, reward_raw, terminated, truncated, info = env.step(actions)
            done = terminated or truncated

            reward_scaled = reward_raw / REWARD_SCALE_FACTOR

            agent.memory.push(state, actions, reward_scaled, next_state, done)
            agent.train()

            # --- DETAILED LOGGING (for Component 1) ---
            #if step_count % LOG_STEP_INTERVAL == 0:
            comp_index = 0

            # State features
            age, tsm, hazard, R, RUL, MTTF, L, MTTR, a_prev, _ = state[comp_index]

            # Calculate current dynamic Operating cost for display
            dynamic_op_cost = env.COST_OP_HOUR_BASE * (1.0 + env.OP_HAZARD_SCALE * hazard)

            print("\n[Ep: {episode} | Step: {step_count} | Time: {age:.0f} hrs | TSM: {tsm:.0f} hrs | Epsilon: {agent.epsilon:.4f}]")
            print("  Component 1 ({env.component_names[comp_index]}):")
            print("    Weibull Age (t): {age:.0f} hrs")
            print("    Reliability (R): {R:.4f}")
            print("    Hazard Rate (λ): {hazard:.6f}")
            print("    RUL Estimate: {RUL:.0f} hrs")
            print("    Prev Action (a_prev): {ACTION_MAP[int(a_prev)]}")
            print("    Dynamic Op Cost: {dynamic_op_cost:.2f} Rs/hr | Current MTTR: {MTTR:.2f} hrs")
            print("    Action Taken: {ACTION_MAP[actions[comp_index]]} (All Actions: {actions})")
            print("    Cost/Reward (Raw): {reward_raw:,.0f} | (Scaled): {reward_scaled:.2f}")

            state = next_state
            episode_reward_raw += reward_raw
            episode_reward_scaled += reward_scaled
            step_count += 1

        # --- END OF EPISODE LOGGING ---
        if episode % 10 == 0 or episode == EPISODES:
            print("\n--- Episode {episode}/{EPISODES} Summary ---")
            print("TOTAL COST (Raw): {episode_reward_raw:,.0f} (Note: Reward is negative cost)")
            print("Steps: {step_count} | Total Time: {step_count * env.TIME_STEP} hrs")
            print("Epsilon: {agent.epsilon:.4f} | Final R (Comp 1): {state[0, 3]:.4f}")
            print("-" * 40)

    env.close()
    print("Training complete.")

if __name__ == "__main__":
    tf.config.experimental.set_visible_devices([], 'GPU')
    print("TensorFlow Version: {tf.__version__}")

    train_ddqn()
# Out:
# TensorFlow Version: 2.19.0
# --- DDQN Training Start ---
# Environment: 1 Component. Max Age: 10000.0 hrs. R_min: 0.15
# PM Fixed Cost: 3,000 Rs
# PM Imperfect Restoration: 85% of R_prev
# MTTR Reliability Penalty (x): 5.0
# Operating Cost Hazard Scale (x): 40,000 (Highly Aggressive)
# Reward Scaling: 1 / 1000
#
# [Ep: 1 | Step: 0 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -10 | (Scaled): -0.01
#
# [Ep: 1 | Step: 1 | Time: 1 hrs | TSM: 1 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000006
#     RUL Estimate: 4008 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 12.35 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -12 | (Scaled): -0.01
#
# [Ep: 1 | Step: 2 | Time: 2 hrs | TSM: 2 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 2 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000009
#     RUL Estimate: 4007 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 13.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,014 | (Scaled): -30.01
#
# [Ep: 1 | Step: 3 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 4 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: PM (Planned) (All Actions: [1])
#     Cost/Reward (Raw): -7,010 | (Scaled): -7.01
#
# [Ep: 1 | Step: 5 | Time: 773 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 773 hrs
#     Reliability (R): 0.8500
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3236 hrs
#     Prev Action (a_prev): PM (Planned)
#     Dynamic Op Cost: 145.48 Rs/hr | Current MTTR: 52.50 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -145 | (Scaled): -0.15
#
# [Ep: 1 | Step: 6 | Time: 774 hrs | TSM: 1 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 774 hrs
#     Reliability (R): 0.8497
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3235 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 145.59 Rs/hr | Current MTTR: 52.54 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 1 | Step: 7 | Time: 775 hrs | TSM: 2 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 775 hrs
#     Reliability (R): 0.8494
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3234 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 145.69 Rs/hr | Current MTTR: 52.59 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -41,439 | (Scaled): -41.44
#
# [Ep: 1 | Step: 8 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 9 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 10 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -10 | (Scaled): -0.01
#
# [Ep: 1 | Step: 11 | Time: 1 hrs | TSM: 1 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000006
#     RUL Estimate: 4008 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 12.35 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -12 | (Scaled): -0.01
#
# [Ep: 1 | Step: 12 | Time: 2 hrs | TSM: 2 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 2 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000009
#     RUL Estimate: 4007 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 13.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -14 | (Scaled): -0.01
#
# [Ep: 1 | Step: 13 | Time: 3 hrs | TSM: 3 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 3 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000011
#     RUL Estimate: 4006 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 14.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -15 | (Scaled): -0.01
#
# [Ep: 1 | Step: 14 | Time: 4 hrs | TSM: 4 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 4 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000014
#     RUL Estimate: 4005 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 15.46 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,018 | (Scaled): -30.02
#
# [Ep: 1 | Step: 15 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 16 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: PM (Planned) (All Actions: [1])
#     Cost/Reward (Raw): -7,010 | (Scaled): -7.01
#
# [Ep: 1 | Step: 17 | Time: 773 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 773 hrs
#     Reliability (R): 0.8500
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3236 hrs
#     Prev Action (a_prev): PM (Planned)
#     Dynamic Op Cost: 145.48 Rs/hr | Current MTTR: 52.50 hrs
#     Action Taken: PM (Planned) (All Actions: [1])
#     Cost/Reward (Raw): -7,145 | (Scaled): -7.15
#
# [Ep: 1 | Step: 18 | Time: 1188 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1188 hrs
#     Reliability (R): 0.7225
#     Hazard Rate (λ): 0.000440
#     RUL Estimate: 2821 hrs
#     Prev Action (a_prev): PM (Planned)
#     Dynamic Op Cost: 186.17 Rs/hr | Current MTTR: 71.62 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -186 | (Scaled): -0.19
#
# [Ep: 1 | Step: 19 | Time: 1189 hrs | TSM: 1 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1189 hrs
#     Reliability (R): 0.7222
#     Hazard Rate (λ): 0.000441
#     RUL Estimate: 2820 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 186.26 Rs/hr | Current MTTR: 71.67 hrs
#     Action Taken: PM (Planned) (All Actions: [1])
#     Cost/Reward (Raw): -7,186 | (Scaled): -7.19
#
# [Ep: 1 | Step: 20 | Time: 1529 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1529 hrs
#     Reliability (R): 0.6139
#     Hazard Rate (λ): 0.000514
#     RUL Estimate: 2479 hrs
#     Prev Action (a_prev): PM (Planned)
#     Dynamic Op Cost: 215.49 Rs/hr | Current MTTR: 87.92 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -59,176 | (Scaled): -59.18
#
# [Ep: 1 | Step: 21 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 22 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -10 | (Scaled): -0.01
#
# [Ep: 1 | Step: 23 | Time: 1 hrs | TSM: 1 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000006
#     RUL Estimate: 4008 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 12.35 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -12 | (Scaled): -0.01
#
# [Ep: 1 | Step: 24 | Time: 2 hrs | TSM: 2 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 2 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000009
#     RUL Estimate: 4007 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 13.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -14 | (Scaled): -0.01
#
# [Ep: 1 | Step: 25 | Time: 3 hrs | TSM: 3 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 3 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000011
#     RUL Estimate: 4006 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 14.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -15 | (Scaled): -0.01
#
# [Ep: 1 | Step: 26 | Time: 4 hrs | TSM: 4 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 4 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000014
#     RUL Estimate: 4005 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 15.46 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -15 | (Scaled): -0.02
#
# [Ep: 1 | Step: 27 | Time: 5 hrs | TSM: 5 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 5 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000016
#     RUL Estimate: 4004 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 16.26 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,020 | (Scaled): -30.02
#
# [Ep: 1 | Step: 28 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 29 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,010 | (Scaled): -30.01
#
# [Ep: 1 | Step: 30 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 1.0000]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -10 | (Scaled): -0.01
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
#     Hazard Rate (λ): 0.000034
#     RUL Estimate: 3991 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 23.68 Rs/hr | Current MTTR: 30.06 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -24 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1756 | Time: 19 hrs | TSM: 19 hrs | Epsilon: 0.0387]
#   Component 1 (Electrodes):
#     Weibull Age (t): 19 hrs
#     Reliability (R): 0.9996
#     Hazard Rate (λ): 0.000035
#     RUL Estimate: 3990 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 24.13 Rs/hr | Current MTTR: 30.06 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -24 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1757 | Time: 20 hrs | TSM: 20 hrs | Epsilon: 0.0386]
#   Component 1 (Electrodes):
#     Weibull Age (t): 20 hrs
#     Reliability (R): 0.9995
#     Hazard Rate (λ): 0.000036
#     RUL Estimate: 3989 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 24.58 Rs/hr | Current MTTR: 30.07 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -25 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1758 | Time: 21 hrs | TSM: 21 hrs | Epsilon: 0.0386]
#   Component 1 (Electrodes):
#     Weibull Age (t): 21 hrs
#     Reliability (R): 0.9995
#     Hazard Rate (λ): 0.000038
#     RUL Estimate: 3988 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 25.02 Rs/hr | Current MTTR: 30.07 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -25 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1759 | Time: 22 hrs | TSM: 22 hrs | Epsilon: 0.0386]
#   Component 1 (Electrodes):
#     Weibull Age (t): 22 hrs
#     Reliability (R): 0.9995
#     Hazard Rate (λ): 0.000039
#     RUL Estimate: 3987 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 25.46 Rs/hr | Current MTTR: 30.08 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -25 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1760 | Time: 23 hrs | TSM: 23 hrs | Epsilon: 0.0386]
#   Component 1 (Electrodes):
#     Weibull Age (t): 23 hrs
#     Reliability (R): 0.9994
#     Hazard Rate (λ): 0.000040
#     RUL Estimate: 3986 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 25.88 Rs/hr | Current MTTR: 30.09 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -26 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1761 | Time: 24 hrs | TSM: 24 hrs | Epsilon: 0.0386]
#   Component 1 (Electrodes):
#     Weibull Age (t): 24 hrs
#     Reliability (R): 0.9994
#     Hazard Rate (λ): 0.000041
#     RUL Estimate: 3985 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 26.30 Rs/hr | Current MTTR: 30.09 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -26 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1762 | Time: 25 hrs | TSM: 25 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 25 hrs
#     Reliability (R): 0.9994
#     Hazard Rate (λ): 0.000042
#     RUL Estimate: 3984 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 26.71 Rs/hr | Current MTTR: 30.10 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -27 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1763 | Time: 26 hrs | TSM: 26 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 26 hrs
#     Reliability (R): 0.9993
#     Hazard Rate (λ): 0.000043
#     RUL Estimate: 3983 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 27.12 Rs/hr | Current MTTR: 30.10 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -27 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1764 | Time: 27 hrs | TSM: 27 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 27 hrs
#     Reliability (R): 0.9993
#     Hazard Rate (λ): 0.000044
#     RUL Estimate: 3982 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 27.51 Rs/hr | Current MTTR: 30.11 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -28 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1765 | Time: 28 hrs | TSM: 28 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 28 hrs
#     Reliability (R): 0.9992
#     Hazard Rate (λ): 0.000045
#     RUL Estimate: 3981 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 27.91 Rs/hr | Current MTTR: 30.12 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -28 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1766 | Time: 29 hrs | TSM: 29 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 29 hrs
#     Reliability (R): 0.9992
#     Hazard Rate (λ): 0.000046
#     RUL Estimate: 3980 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 28.29 Rs/hr | Current MTTR: 30.12 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -28 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1767 | Time: 30 hrs | TSM: 30 hrs | Epsilon: 0.0385]
#   Component 1 (Electrodes):
#     Weibull Age (t): 30 hrs
#     Reliability (R): 0.9991
#     Hazard Rate (λ): 0.000047
#     RUL Estimate: 3979 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 28.68 Rs/hr | Current MTTR: 30.13 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -29 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1768 | Time: 31 hrs | TSM: 31 hrs | Epsilon: 0.0384]
#   Component 1 (Electrodes):
#     Weibull Age (t): 31 hrs
#     Reliability (R): 0.9991
#     Hazard Rate (λ): 0.000048
#     RUL Estimate: 3978 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 29.05 Rs/hr | Current MTTR: 30.14 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -29 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1769 | Time: 32 hrs | TSM: 32 hrs | Epsilon: 0.0384]
#   Component 1 (Electrodes):
#     Weibull Age (t): 32 hrs
#     Reliability (R): 0.9990
#     Hazard Rate (λ): 0.000049
#     RUL Estimate: 3977 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 29.43 Rs/hr | Current MTTR: 30.14 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -29 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1770 | Time: 33 hrs | TSM: 33 hrs | Epsilon: 0.0384]
#   Component 1 (Electrodes):
#     Weibull Age (t): 33 hrs
#     Reliability (R): 0.9990
#     Hazard Rate (λ): 0.000049
#     RUL Estimate: 3976 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 29.79 Rs/hr | Current MTTR: 30.15 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -30 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1771 | Time: 34 hrs | TSM: 34 hrs | Epsilon: 0.0384]
#   Component 1 (Electrodes):
#     Weibull Age (t): 34 hrs
#     Reliability (R): 0.9989
#     Hazard Rate (λ): 0.000050
#     RUL Estimate: 3975 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 30.16 Rs/hr | Current MTTR: 30.16 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -30 | (Scaled): -0.03
#
# [Ep: 19 | Step: 1772 | Time: 35 hrs | TSM: 35 hrs | Epsilon: 0.0384]
#   Component 1 (Electrodes):
#     Weibull Age (t): 35 hrs
#     Reliability (R): 0.9989
#     Hazard Rate (λ): 0.000051
#     RUL Estimate: 3974 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 30.52 Rs/hr | Current MTTR: 30.17 hrs
#     Action Taken: CM (Corrective) (All Actions: [2])
#     Cost/Reward (Raw): -30,114 | (Scaled): -30.11
#
# [Ep: 19 | Step: 1773 | Time: 0 hrs | TSM: 0 hrs | Epsilon: 0.0383]
#   Component 1 (Electrodes):
#     Weibull Age (t): 0 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000000
#     RUL Estimate: 4009 hrs
#     Prev Action (a_prev): CM (Corrective)
#     Dynamic Op Cost: 10.00 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -10 | (Scaled): -0.01
#
# [Ep: 19 | Step: 1774 | Time: 1 hrs | TSM: 1 hrs | Epsilon: 0.0383]
#   Component 1 (Electrodes):
#     Weibull Age (t): 1 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000006
#     RUL Estimate: 4008 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 12.35 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -12 | (Scaled): -0.01
#
# [Ep: 19 | Step: 1775 | Time: 2 hrs | TSM: 2 hrs | Epsilon: 0.0383]
#   Component 1 (Electrodes):
#     Weibull Age (t): 2 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000009
#     RUL Estimate: 4007 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 13.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -14 | (Scaled): -0.01
#
# [Ep: 19 | Step: 1776 | Time: 3 hrs | TSM: 3 hrs | Epsilon: 0.0383]
#   Component 1 (Electrodes):
#     Weibull Age (t): 3 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000011
#     RUL Estimate: 4006 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 14.58 Rs/hr | Current MTTR: 30.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -15 | (Scaled): -0.01
#
# [Ep: 19 | Step: 1777 | Time: 4 hrs | TSM: 4 hrs | Epsilon: 0.0383]
#   Component 1 (Electrodes):
#     Weibull Age (t): 4 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000014
#     RUL Estimate: 4005 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 15.46 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -15 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1778 | Time: 5 hrs | TSM: 5 hrs | Epsilon: 0.0382]
#   Component 1 (Electrodes):
#     Weibull Age (t): 5 hrs
#     Reliability (R): 1.0000
#     Hazard Rate (λ): 0.000016
#     RUL Estimate: 4004 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 16.26 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -16 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1779 | Time: 6 hrs | TSM: 6 hrs | Epsilon: 0.0382]
#   Component 1 (Electrodes):
#     Weibull Age (t): 6 hrs
#     Reliability (R): 0.9999
#     Hazard Rate (λ): 0.000017
#     RUL Estimate: 4003 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 17.00 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -17 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1780 | Time: 7 hrs | TSM: 7 hrs | Epsilon: 0.0382]
#   Component 1 (Electrodes):
#     Weibull Age (t): 7 hrs
#     Reliability (R): 0.9999
#     Hazard Rate (λ): 0.000019
#     RUL Estimate: 4002 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 17.69 Rs/hr | Current MTTR: 30.01 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -18 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1781 | Time: 8 hrs | TSM: 8 hrs | Epsilon: 0.0382]
#   Component 1 (Electrodes):
#     Weibull Age (t): 8 hrs
#     Reliability (R): 0.9999
#     Hazard Rate (λ): 0.000021
#     RUL Estimate: 4001 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 18.34 Rs/hr | Current MTTR: 30.02 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -18 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1782 | Time: 9 hrs | TSM: 9 hrs | Epsilon: 0.0382]
#   Component 1 (Electrodes):
#     Weibull Age (t): 9 hrs
#     Reliability (R): 0.9999
#     Hazard Rate (λ): 0.000022
#     RUL Estimate: 4000 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 18.96 Rs/hr | Current MTTR: 30.02 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -19 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1783 | Time: 10 hrs | TSM: 10 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 10 hrs
#     Reliability (R): 0.9999
#     Hazard Rate (λ): 0.000024
#     RUL Estimate: 3999 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 19.56 Rs/hr | Current MTTR: 30.02 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -20 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1784 | Time: 11 hrs | TSM: 11 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 11 hrs
#     Reliability (R): 0.9998
#     Hazard Rate (λ): 0.000025
#     RUL Estimate: 3998 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 20.13 Rs/hr | Current MTTR: 30.03 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -20 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1785 | Time: 12 hrs | TSM: 12 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 12 hrs
#     Reliability (R): 0.9998
#     Hazard Rate (λ): 0.000027
#     RUL Estimate: 3997 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 20.68 Rs/hr | Current MTTR: 30.03 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -21 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1786 | Time: 13 hrs | TSM: 13 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 13 hrs
#     Reliability (R): 0.9998
#     Hazard Rate (λ): 0.000028
#     RUL Estimate: 3996 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 21.21 Rs/hr | Current MTTR: 30.03 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -21 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1787 | Time: 14 hrs | TSM: 14 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 14 hrs
#     Reliability (R): 0.9997
#     Hazard Rate (λ): 0.000029
#     RUL Estimate: 3995 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 21.73 Rs/hr | Current MTTR: 30.04 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -22 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1788 | Time: 15 hrs | TSM: 15 hrs | Epsilon: 0.0381]
#   Component 1 (Electrodes):
#     Weibull Age (t): 15 hrs
#     Reliability (R): 0.9997
#     Hazard Rate (λ): 0.000031
#     RUL Estimate: 3994 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 22.24 Rs/hr | Current MTTR: 30.04 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -22 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1789 | Time: 16 hrs | TSM: 16 hrs | Epsilon: 0.0380]
#   Component 1 (Electrodes):
#     Weibull Age (t): 16 hrs
#     Reliability (R): 0.9997
#     Hazard Rate (λ): 0.000032
#     RUL Estimate: 3993 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 22.73 Rs/hr | Current MTTR: 30.05 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -23 | (Scaled): -0.02
#
# [Ep: 19 | Step: 1790 | Time: 17 hrs | TSM: 17 hrs | Epsilon: 0.0380]
#   Component 1 (Electrodes):
#     Weibull Age (t): 17 hrs
#     Reliability (R): 0.9997
#     Hazard Rate (λ): 0.000033
#     RUL Estimate: 3992 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 23.21 Rs/hr | Current MTTR: 30.05 hrs
#     Action Taken: PM (Planned) (All Actions: [1])
#     Cost/Reward (Raw): -7,023 | (Scaled): -7.02
#
# [Ep: 19 | Step: 1791 | Time: 774 hrs | TSM: 0 hrs | Epsilon: 0.0380]
#   Component 1 (Electrodes):
#     Weibull Age (t): 774 hrs
#     Reliability (R): 0.8497
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3235 hrs
#     Prev Action (a_prev): PM (Planned)
#     Dynamic Op Cost: 145.59 Rs/hr | Current MTTR: 52.54 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1792 | Time: 775 hrs | TSM: 1 hrs | Epsilon: 0.0380]
#   Component 1 (Electrodes):
#     Weibull Age (t): 775 hrs
#     Reliability (R): 0.8494
#     Hazard Rate (λ): 0.000339
#     RUL Estimate: 3234 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 145.70 Rs/hr | Current MTTR: 52.59 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1793 | Time: 776 hrs | TSM: 2 hrs | Epsilon: 0.0380]
#   Component 1 (Electrodes):
#     Weibull Age (t): 776 hrs
#     Reliability (R): 0.8491
#     Hazard Rate (λ): 0.000340
#     RUL Estimate: 3233 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 145.80 Rs/hr | Current MTTR: 52.63 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1794 | Time: 777 hrs | TSM: 3 hrs | Epsilon: 0.0379]
#   Component 1 (Electrodes):
#     Weibull Age (t): 777 hrs
#     Reliability (R): 0.8488
#     Hazard Rate (λ): 0.000340
#     RUL Estimate: 3232 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 145.91 Rs/hr | Current MTTR: 52.67 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1795 | Time: 778 hrs | TSM: 4 hrs | Epsilon: 0.0379]
#   Component 1 (Electrodes):
#     Weibull Age (t): 778 hrs
#     Reliability (R): 0.8486
#     Hazard Rate (λ): 0.000340
#     RUL Estimate: 3231 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.02 Rs/hr | Current MTTR: 52.72 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1796 | Time: 779 hrs | TSM: 5 hrs | Epsilon: 0.0379]
#   Component 1 (Electrodes):
#     Weibull Age (t): 779 hrs
#     Reliability (R): 0.8483
#     Hazard Rate (λ): 0.000340
#     RUL Estimate: 3230 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.12 Rs/hr | Current MTTR: 52.76 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1797 | Time: 780 hrs | TSM: 6 hrs | Epsilon: 0.0379]
#   Component 1 (Electrodes):
#     Weibull Age (t): 780 hrs
#     Reliability (R): 0.8480
#     Hazard Rate (λ): 0.000341
#     RUL Estimate: 3229 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.23 Rs/hr | Current MTTR: 52.80 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1798 | Time: 781 hrs | TSM: 7 hrs | Epsilon: 0.0379]
#   Component 1 (Electrodes):
#     Weibull Age (t): 781 hrs
#     Reliability (R): 0.8477
#     Hazard Rate (λ): 0.000341
#     RUL Estimate: 3228 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.34 Rs/hr | Current MTTR: 52.85 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1799 | Time: 782 hrs | TSM: 8 hrs | Epsilon: 0.0378]
#   Component 1 (Electrodes):
#     Weibull Age (t): 782 hrs
#     Reliability (R): 0.8474
#     Hazard Rate (λ): 0.000341
#     RUL Estimate: 3227 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.44 Rs/hr | Current MTTR: 52.89 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -146 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1800 | Time: 783 hrs | TSM: 9 hrs | Epsilon: 0.0378]
#   Component 1 (Electrodes):
#     Weibull Age (t): 783 hrs
#     Reliability (R): 0.8471
#     Hazard Rate (λ): 0.000341
#     RUL Estimate: 3226 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.55 Rs/hr | Current MTTR: 52.93 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1801 | Time: 784 hrs | TSM: 10 hrs | Epsilon: 0.0378]
#   Component 1 (Electrodes):
#     Weibull Age (t): 784 hrs
#     Reliability (R): 0.8468
#     Hazard Rate (λ): 0.000342
#     RUL Estimate: 3225 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.66 Rs/hr | Current MTTR: 52.98 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1802 | Time: 785 hrs | TSM: 11 hrs | Epsilon: 0.0378]
#   Component 1 (Electrodes):
#     Weibull Age (t): 785 hrs
#     Reliability (R): 0.8465
#     Hazard Rate (λ): 0.000342
#     RUL Estimate: 3224 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.76 Rs/hr | Current MTTR: 53.02 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1803 | Time: 786 hrs | TSM: 12 hrs | Epsilon: 0.0378]
#   Component 1 (Electrodes):
#     Weibull Age (t): 786 hrs
#     Reliability (R): 0.8462
#     Hazard Rate (λ): 0.000342
#     RUL Estimate: 3223 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.87 Rs/hr | Current MTTR: 53.06 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1804 | Time: 787 hrs | TSM: 13 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 787 hrs
#     Reliability (R): 0.8459
#     Hazard Rate (λ): 0.000342
#     RUL Estimate: 3222 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 146.98 Rs/hr | Current MTTR: 53.11 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1805 | Time: 788 hrs | TSM: 14 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 788 hrs
#     Reliability (R): 0.8457
#     Hazard Rate (λ): 0.000343
#     RUL Estimate: 3221 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.08 Rs/hr | Current MTTR: 53.15 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1806 | Time: 789 hrs | TSM: 15 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 789 hrs
#     Reliability (R): 0.8454
#     Hazard Rate (λ): 0.000343
#     RUL Estimate: 3220 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.19 Rs/hr | Current MTTR: 53.19 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1807 | Time: 790 hrs | TSM: 16 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 790 hrs
#     Reliability (R): 0.8451
#     Hazard Rate (λ): 0.000343
#     RUL Estimate: 3219 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.29 Rs/hr | Current MTTR: 53.24 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1808 | Time: 791 hrs | TSM: 17 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 791 hrs
#     Reliability (R): 0.8448
#     Hazard Rate (λ): 0.000344
#     RUL Estimate: 3218 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.40 Rs/hr | Current MTTR: 53.28 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -147 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1809 | Time: 792 hrs | TSM: 18 hrs | Epsilon: 0.0377]
#   Component 1 (Electrodes):
#     Weibull Age (t): 792 hrs
#     Reliability (R): 0.8445
#     Hazard Rate (λ): 0.000344
#     RUL Estimate: 3217 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.51 Rs/hr | Current MTTR: 53.33 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1810 | Time: 793 hrs | TSM: 19 hrs | Epsilon: 0.0376]
#   Component 1 (Electrodes):
#     Weibull Age (t): 793 hrs
#     Reliability (R): 0.8442
#     Hazard Rate (λ): 0.000344
#     RUL Estimate: 3216 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.61 Rs/hr | Current MTTR: 53.37 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1811 | Time: 794 hrs | TSM: 20 hrs | Epsilon: 0.0376]
#   Component 1 (Electrodes):
#     Weibull Age (t): 794 hrs
#     Reliability (R): 0.8439
#     Hazard Rate (λ): 0.000344
#     RUL Estimate: 3215 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.72 Rs/hr | Current MTTR: 53.41 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1812 | Time: 795 hrs | TSM: 21 hrs | Epsilon: 0.0376]
#   Component 1 (Electrodes):
#     Weibull Age (t): 795 hrs
#     Reliability (R): 0.8436
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3214 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.82 Rs/hr | Current MTTR: 53.46 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1813 | Time: 796 hrs | TSM: 22 hrs | Epsilon: 0.0376]
#   Component 1 (Electrodes):
#     Weibull Age (t): 796 hrs
#     Reliability (R): 0.8433
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3213 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 147.93 Rs/hr | Current MTTR: 53.50 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1814 | Time: 797 hrs | TSM: 23 hrs | Epsilon: 0.0376]
#   Component 1 (Electrodes):
#     Weibull Age (t): 797 hrs
#     Reliability (R): 0.8430
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3212 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.04 Rs/hr | Current MTTR: 53.54 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1815 | Time: 798 hrs | TSM: 24 hrs | Epsilon: 0.0375]
#   Component 1 (Electrodes):
#     Weibull Age (t): 798 hrs
#     Reliability (R): 0.8428
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3211 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.14 Rs/hr | Current MTTR: 53.59 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1816 | Time: 799 hrs | TSM: 25 hrs | Epsilon: 0.0375]
#   Component 1 (Electrodes):
#     Weibull Age (t): 799 hrs
#     Reliability (R): 0.8425
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3210 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.25 Rs/hr | Current MTTR: 53.63 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1817 | Time: 800 hrs | TSM: 26 hrs | Epsilon: 0.0375]
#   Component 1 (Electrodes):
#     Weibull Age (t): 800 hrs
#     Reliability (R): 0.8422
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3209 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.35 Rs/hr | Current MTTR: 53.67 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1818 | Time: 801 hrs | TSM: 27 hrs | Epsilon: 0.0375]
#   Component 1 (Electrodes):
#     Weibull Age (t): 801 hrs
#     Reliability (R): 0.8419
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3208 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.46 Rs/hr | Current MTTR: 53.72 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1819 | Time: 802 hrs | TSM: 28 hrs | Epsilon: 0.0375]
#   Component 1 (Electrodes):
#     Weibull Age (t): 802 hrs
#     Reliability (R): 0.8416
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3207 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.56 Rs/hr | Current MTTR: 53.76 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1820 | Time: 803 hrs | TSM: 29 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 803 hrs
#     Reliability (R): 0.8413
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3206 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.67 Rs/hr | Current MTTR: 53.81 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1821 | Time: 804 hrs | TSM: 30 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 804 hrs
#     Reliability (R): 0.8410
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3205 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.77 Rs/hr | Current MTTR: 53.85 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1822 | Time: 805 hrs | TSM: 31 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 805 hrs
#     Reliability (R): 0.8407
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3204 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.88 Rs/hr | Current MTTR: 53.89 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1823 | Time: 806 hrs | TSM: 32 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 806 hrs
#     Reliability (R): 0.8404
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3203 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.99 Rs/hr | Current MTTR: 53.94 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1824 | Time: 807 hrs | TSM: 33 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 807 hrs
#     Reliability (R): 0.8401
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3202 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.09 Rs/hr | Current MTTR: 53.98 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1825 | Time: 808 hrs | TSM: 34 hrs | Epsilon: 0.0374]
#   Component 1 (Electrodes):
#     Weibull Age (t): 808 hrs
#     Reliability (R): 0.8398
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3201 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.20 Rs/hr | Current MTTR: 54.02 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1826 | Time: 809 hrs | TSM: 35 hrs | Epsilon: 0.0373]
#   Component 1 (Electrodes):
#     Weibull Age (t): 809 hrs
#     Reliability (R): 0.8395
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3200 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.30 Rs/hr | Current MTTR: 54.07 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1827 | Time: 810 hrs | TSM: 36 hrs | Epsilon: 0.0373]
#   Component 1 (Electrodes):
#     Weibull Age (t): 810 hrs
#     Reliability (R): 0.8393
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3199 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.41 Rs/hr | Current MTTR: 54.11 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1828 | Time: 811 hrs | TSM: 37 hrs | Epsilon: 0.0373]
#   Component 1 (Electrodes):
#     Weibull Age (t): 811 hrs
#     Reliability (R): 0.8390
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3198 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.51 Rs/hr | Current MTTR: 54.16 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1829 | Time: 812 hrs | TSM: 38 hrs | Epsilon: 0.0373]
#   Component 1 (Electrodes):
#     Weibull Age (t): 812 hrs
#     Reliability (R): 0.8387
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3197 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.62 Rs/hr | Current MTTR: 54.20 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1830 | Time: 813 hrs | TSM: 39 hrs | Epsilon: 0.0373]
#   Component 1 (Electrodes):
#     Weibull Age (t): 813 hrs
#     Reliability (R): 0.8384
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3196 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.72 Rs/hr | Current MTTR: 54.24 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1831 | Time: 814 hrs | TSM: 40 hrs | Epsilon: 0.0372]
#   Component 1 (Electrodes):
#     Weibull Age (t): 814 hrs
#     Reliability (R): 0.8381
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3195 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.83 Rs/hr | Current MTTR: 54.29 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1832 | Time: 815 hrs | TSM: 41 hrs | Epsilon: 0.0372]
#   Component 1 (Electrodes):
#     Weibull Age (t): 815 hrs
#     Reliability (R): 0.8378
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3194 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.93 Rs/hr | Current MTTR: 54.33 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1833 | Time: 816 hrs | TSM: 42 hrs | Epsilon: 0.0372]
#   Component 1 (Electrodes):
#     Weibull Age (t): 816 hrs
#     Reliability (R): 0.8375
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3193 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.04 Rs/hr | Current MTTR: 54.38 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1834 | Time: 817 hrs | TSM: 43 hrs | Epsilon: 0.0372]
#   Component 1 (Electrodes):
#     Weibull Age (t): 817 hrs
#     Reliability (R): 0.8372
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3192 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.14 Rs/hr | Current MTTR: 54.42 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1835 | Time: 818 hrs | TSM: 44 hrs | Epsilon: 0.0372]
#   Component 1 (Electrodes):
#     Weibull Age (t): 818 hrs
#     Reliability (R): 0.8369
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3191 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.24 Rs/hr | Current MTTR: 54.46 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1836 | Time: 819 hrs | TSM: 45 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 819 hrs
#     Reliability (R): 0.8366
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3190 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.35 Rs/hr | Current MTTR: 54.51 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1837 | Time: 820 hrs | TSM: 46 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 820 hrs
#     Reliability (R): 0.8363
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3189 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.45 Rs/hr | Current MTTR: 54.55 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1838 | Time: 821 hrs | TSM: 47 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 821 hrs
#     Reliability (R): 0.8360
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3188 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.56 Rs/hr | Current MTTR: 54.60 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1839 | Time: 822 hrs | TSM: 48 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 822 hrs
#     Reliability (R): 0.8357
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3187 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.66 Rs/hr | Current MTTR: 54.64 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1840 | Time: 823 hrs | TSM: 49 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 823 hrs
#     Reliability (R): 0.8354
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3186 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.77 Rs/hr | Current MTTR: 54.68 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1841 | Time: 824 hrs | TSM: 50 hrs | Epsilon: 0.0371]
#   Component 1 (Electrodes):
#     Weibull Age (t): 824 hrs
#     Reliability (R): 0.8351
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3185 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.87 Rs/hr | Current MTTR: 54.73 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1842 | Time: 825 hrs | TSM: 51 hrs | Epsilon: 0.0370]
#   Component 1 (Electrodes):
#     Weibull Age (t): 825 hrs
#     Reliability (R): 0.8349
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3184 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.98 Rs/hr | Current MTTR: 54.77 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1843 | Time: 826 hrs | TSM: 52 hrs | Epsilon: 0.0370]
#   Component 1 (Electrodes):
#     Weibull Age (t): 826 hrs
#     Reliability (R): 0.8346
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3183 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.08 Rs/hr | Current MTTR: 54.82 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1844 | Time: 827 hrs | TSM: 53 hrs | Epsilon: 0.0370]
#   Component 1 (Electrodes):
#     Weibull Age (t): 827 hrs
#     Reliability (R): 0.8343
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3182 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.18 Rs/hr | Current MTTR: 54.86 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 1845 | Time: 828 hrs | TSM: 54 hrs | Epsilon: 0.0370]
#   Component 1 (Electrodes):
#     Weibull Age (t): 828 hrs
#     Reliability (R): 0.8340
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3181 hrs
# ...
#     Weibull Age (t): 797 hrs
#     Reliability (R): 0.8430
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3212 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.06 Rs/hr | Current MTTR: 53.55 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2170 | Time: 798 hrs | TSM: 15 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 798 hrs
#     Reliability (R): 0.8427
#     Hazard Rate (λ): 0.000345
#     RUL Estimate: 3211 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.16 Rs/hr | Current MTTR: 53.60 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2171 | Time: 799 hrs | TSM: 16 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 799 hrs
#     Reliability (R): 0.8424
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3210 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.27 Rs/hr | Current MTTR: 53.64 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2172 | Time: 800 hrs | TSM: 17 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 800 hrs
#     Reliability (R): 0.8421
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3209 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.38 Rs/hr | Current MTTR: 53.68 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2173 | Time: 801 hrs | TSM: 18 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 801 hrs
#     Reliability (R): 0.8418
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3208 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.48 Rs/hr | Current MTTR: 53.73 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -148 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2174 | Time: 802 hrs | TSM: 19 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 802 hrs
#     Reliability (R): 0.8415
#     Hazard Rate (λ): 0.000346
#     RUL Estimate: 3207 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.59 Rs/hr | Current MTTR: 53.77 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2175 | Time: 803 hrs | TSM: 20 hrs | Epsilon: 0.0314]
#   Component 1 (Electrodes):
#     Weibull Age (t): 803 hrs
#     Reliability (R): 0.8412
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3206 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.69 Rs/hr | Current MTTR: 53.81 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2176 | Time: 804 hrs | TSM: 21 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 804 hrs
#     Reliability (R): 0.8409
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3205 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.80 Rs/hr | Current MTTR: 53.86 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2177 | Time: 805 hrs | TSM: 22 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 805 hrs
#     Reliability (R): 0.8407
#     Hazard Rate (λ): 0.000347
#     RUL Estimate: 3204 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 148.90 Rs/hr | Current MTTR: 53.90 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2178 | Time: 806 hrs | TSM: 23 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 806 hrs
#     Reliability (R): 0.8404
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3203 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.01 Rs/hr | Current MTTR: 53.95 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2179 | Time: 807 hrs | TSM: 24 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 807 hrs
#     Reliability (R): 0.8401
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3202 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.11 Rs/hr | Current MTTR: 53.99 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2180 | Time: 808 hrs | TSM: 25 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 808 hrs
#     Reliability (R): 0.8398
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3201 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.22 Rs/hr | Current MTTR: 54.03 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2181 | Time: 809 hrs | TSM: 26 hrs | Epsilon: 0.0313]
#   Component 1 (Electrodes):
#     Weibull Age (t): 809 hrs
#     Reliability (R): 0.8395
#     Hazard Rate (λ): 0.000348
#     RUL Estimate: 3200 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.32 Rs/hr | Current MTTR: 54.08 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2182 | Time: 810 hrs | TSM: 27 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 810 hrs
#     Reliability (R): 0.8392
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3199 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.43 Rs/hr | Current MTTR: 54.12 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -149 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2183 | Time: 811 hrs | TSM: 28 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 811 hrs
#     Reliability (R): 0.8389
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3198 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.53 Rs/hr | Current MTTR: 54.17 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2184 | Time: 812 hrs | TSM: 29 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 812 hrs
#     Reliability (R): 0.8386
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3197 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.64 Rs/hr | Current MTTR: 54.21 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2185 | Time: 813 hrs | TSM: 30 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 813 hrs
#     Reliability (R): 0.8383
#     Hazard Rate (λ): 0.000349
#     RUL Estimate: 3196 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.74 Rs/hr | Current MTTR: 54.25 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2186 | Time: 814 hrs | TSM: 31 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 814 hrs
#     Reliability (R): 0.8380
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3195 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.85 Rs/hr | Current MTTR: 54.30 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2187 | Time: 815 hrs | TSM: 32 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 815 hrs
#     Reliability (R): 0.8377
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3194 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 149.95 Rs/hr | Current MTTR: 54.34 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2188 | Time: 816 hrs | TSM: 33 hrs | Epsilon: 0.0312]
#   Component 1 (Electrodes):
#     Weibull Age (t): 816 hrs
#     Reliability (R): 0.8374
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3193 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.06 Rs/hr | Current MTTR: 54.38 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2189 | Time: 817 hrs | TSM: 34 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 817 hrs
#     Reliability (R): 0.8371
#     Hazard Rate (λ): 0.000350
#     RUL Estimate: 3192 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.16 Rs/hr | Current MTTR: 54.43 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2190 | Time: 818 hrs | TSM: 35 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 818 hrs
#     Reliability (R): 0.8368
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3191 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.27 Rs/hr | Current MTTR: 54.47 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2191 | Time: 819 hrs | TSM: 36 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 819 hrs
#     Reliability (R): 0.8366
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3190 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.37 Rs/hr | Current MTTR: 54.52 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2192 | Time: 820 hrs | TSM: 37 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 820 hrs
#     Reliability (R): 0.8363
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3189 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.48 Rs/hr | Current MTTR: 54.56 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -150 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2193 | Time: 821 hrs | TSM: 38 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 821 hrs
#     Reliability (R): 0.8360
#     Hazard Rate (λ): 0.000351
#     RUL Estimate: 3188 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.58 Rs/hr | Current MTTR: 54.61 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2194 | Time: 822 hrs | TSM: 39 hrs | Epsilon: 0.0311]
#   Component 1 (Electrodes):
#     Weibull Age (t): 822 hrs
#     Reliability (R): 0.8357
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3187 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.68 Rs/hr | Current MTTR: 54.65 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2195 | Time: 823 hrs | TSM: 40 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 823 hrs
#     Reliability (R): 0.8354
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3186 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.79 Rs/hr | Current MTTR: 54.69 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2196 | Time: 824 hrs | TSM: 41 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 824 hrs
#     Reliability (R): 0.8351
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3185 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 150.89 Rs/hr | Current MTTR: 54.74 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2197 | Time: 825 hrs | TSM: 42 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 825 hrs
#     Reliability (R): 0.8348
#     Hazard Rate (λ): 0.000352
#     RUL Estimate: 3184 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.00 Rs/hr | Current MTTR: 54.78 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2198 | Time: 826 hrs | TSM: 43 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 826 hrs
#     Reliability (R): 0.8345
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3183 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.10 Rs/hr | Current MTTR: 54.83 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2199 | Time: 827 hrs | TSM: 44 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 827 hrs
#     Reliability (R): 0.8342
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3182 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.21 Rs/hr | Current MTTR: 54.87 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2200 | Time: 828 hrs | TSM: 45 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 828 hrs
#     Reliability (R): 0.8339
#     Hazard Rate (λ): 0.000353
#     RUL Estimate: 3181 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.31 Rs/hr | Current MTTR: 54.91 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2201 | Time: 829 hrs | TSM: 46 hrs | Epsilon: 0.0310]
#   Component 1 (Electrodes):
#     Weibull Age (t): 829 hrs
#     Reliability (R): 0.8336
#     Hazard Rate (λ): 0.000354
#     RUL Estimate: 3180 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.41 Rs/hr | Current MTTR: 54.96 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -151 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2202 | Time: 830 hrs | TSM: 47 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 830 hrs
#     Reliability (R): 0.8333
#     Hazard Rate (λ): 0.000354
#     RUL Estimate: 3179 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.52 Rs/hr | Current MTTR: 55.00 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2203 | Time: 831 hrs | TSM: 48 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 831 hrs
#     Reliability (R): 0.8330
#     Hazard Rate (λ): 0.000354
#     RUL Estimate: 3178 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.62 Rs/hr | Current MTTR: 55.05 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2204 | Time: 832 hrs | TSM: 49 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 832 hrs
#     Reliability (R): 0.8327
#     Hazard Rate (λ): 0.000354
#     RUL Estimate: 3177 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.73 Rs/hr | Current MTTR: 55.09 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2205 | Time: 833 hrs | TSM: 50 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 833 hrs
#     Reliability (R): 0.8324
#     Hazard Rate (λ): 0.000355
#     RUL Estimate: 3176 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.83 Rs/hr | Current MTTR: 55.14 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2206 | Time: 834 hrs | TSM: 51 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 834 hrs
#     Reliability (R): 0.8321
#     Hazard Rate (λ): 0.000355
#     RUL Estimate: 3175 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 151.93 Rs/hr | Current MTTR: 55.18 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2207 | Time: 835 hrs | TSM: 52 hrs | Epsilon: 0.0309]
#   Component 1 (Electrodes):
#     Weibull Age (t): 835 hrs
#     Reliability (R): 0.8318
#     Hazard Rate (λ): 0.000355
#     RUL Estimate: 3174 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 152.04 Rs/hr | Current MTTR: 55.22 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2208 | Time: 836 hrs | TSM: 53 hrs | Epsilon: 0.0308]
#   Component 1 (Electrodes):
#     Weibull Age (t): 836 hrs
#     Reliability (R): 0.8315
#     Hazard Rate (λ): 0.000355
#     RUL Estimate: 3173 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 152.14 Rs/hr | Current MTTR: 55.27 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
#
# [Ep: 19 | Step: 2209 | Time: 837 hrs | TSM: 54 hrs | Epsilon: 0.0308]
#   Component 1 (Electrodes):
#     Weibull Age (t): 837 hrs
#     Reliability (R): 0.8313
#     Hazard Rate (λ): 0.000356
#     RUL Estimate: 3172 hrs
#     Prev Action (a_prev): NOOP
#     Dynamic Op Cost: 152.25 Rs/hr | Current MTTR: 55.31 hrs
#     Action Taken: NOOP (All Actions: [0])
#     Cost/Reward (Raw): -152 | (Scaled): -0.15
